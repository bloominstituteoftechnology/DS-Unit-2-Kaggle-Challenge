# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 2, Module 2*
#
# ---

# %% [markdown]
# # Random Forests
#
# ## Assignment
# - [ ] Read [“Adopting a Hypothesis-Driven Workflow”](https://outline.com/5S5tsB), a blog post by a Lambda DS student about the Tanzania Waterpumps challenge.
# - [ ] Continue to participate in our Kaggle challenge.
# - [ ] Define a function to wrangle train, validate, and test sets in the same way. Clean outliers and engineer features.
# - [ ] Try Ordinal Encoding.
# - [ ] Try a Random Forest Classifier.
# - [ ] Submit your predictions to our Kaggle competition. (Go to our Kaggle InClass competition webpage. Use the blue **Submit Predictions** button to upload your CSV file. Or you can use the Kaggle API to submit your predictions.)
# - [ ] Commit your notebook to your fork of the GitHub repo.
#
# ## Stretch Goals
#
# ### Doing
# - [ ] Add your own stretch goal(s) !
# - [ ] Do more exploratory data analysis, data cleaning, feature engineering, and feature selection.
# - [ ] Try other [categorical encodings](https://contrib.scikit-learn.org/categorical-encoding/).
# - [ ] Get and plot your feature importances.
# - [ ] Make visualizations and share on Slack.
#
# ### Reading
#
# Top recommendations in _**bold italic:**_
#
# #### Decision Trees
# - A Visual Introduction to Machine Learning, [Part 1: A Decision Tree](http://www.r2d3.us/visual-intro-to-machine-learning-part-1/),  and _**[Part 2: Bias and Variance](http://www.r2d3.us/visual-intro-to-machine-learning-part-2/)**_
# - [Decision Trees: Advantages & Disadvantages](https://christophm.github.io/interpretable-ml-book/tree.html#advantages-2)
# - [How a Russian mathematician constructed a decision tree — by hand — to solve a medical problem](http://fastml.com/how-a-russian-mathematician-constructed-a-decision-tree-by-hand-to-solve-a-medical-problem/)
# - [How decision trees work](https://brohrer.github.io/how_decision_trees_work.html)
# - [Let’s Write a Decision Tree Classifier from Scratch](https://www.youtube.com/watch?v=LDRbO9a6XPU)
#
# #### Random Forests
# - [_An Introduction to Statistical Learning_](http://www-bcf.usc.edu/~gareth/ISL/), Chapter 8: Tree-Based Methods
# - [Coloring with Random Forests](http://structuringtheunstructured.blogspot.com/2017/11/coloring-with-random-forests.html)
# - _**[Random Forests for Complete Beginners: The definitive guide to Random Forests and Decision Trees](https://victorzhou.com/blog/intro-to-random-forests/)**_
#
# #### Categorical encoding for trees
# - [Are categorical variables getting lost in your random forests?](https://roamanalytics.com/2016/10/28/are-categorical-variables-getting-lost-in-your-random-forests/)
# - [Beyond One-Hot: An Exploration of Categorical Variables](http://www.willmcginnis.com/2015/11/29/beyond-one-hot-an-exploration-of-categorical-variables/)
# - _**[Categorical Features and Encoding in Decision Trees](https://medium.com/data-design/visiting-categorical-features-and-encoding-in-decision-trees-53400fa65931)**_
# - _**[Coursera — How to Win a Data Science Competition: Learn from Top Kagglers — Concept of mean encoding](https://www.coursera.org/lecture/competitive-data-science/concept-of-mean-encoding-b5Gxv)**_
# - [Mean (likelihood) encodings: a comprehensive study](https://www.kaggle.com/vprokopev/mean-likelihood-encodings-a-comprehensive-study)
# - [The Mechanics of Machine Learning, Chapter 6: Categorically Speaking](https://mlbook.explained.ai/catvars.html)
#
# #### Imposter Syndrome
# - [Effort Shock and Reward Shock (How The Karate Kid Ruined The Modern World)](http://www.tempobook.com/2014/07/09/effort-shock-and-reward-shock/)
# - [How to manage impostor syndrome in data science](https://towardsdatascience.com/how-to-manage-impostor-syndrome-in-data-science-ad814809f068)
# - ["I am not a real data scientist"](https://brohrer.github.io/imposter_syndrome.html)
# - _**[Imposter Syndrome in Data Science](https://caitlinhudon.com/2018/01/19/imposter-syndrome-in-data-science/)**_
#
#
# ### More Categorical Encodings
#
# **1.** The article **[Categorical Features and Encoding in Decision Trees](https://medium.com/data-design/visiting-categorical-features-and-encoding-in-decision-trees-53400fa65931)** mentions 4 encodings:
#
# - **"Categorical Encoding":** This means using the raw categorical values as-is, not encoded. Scikit-learn doesn't support this, but some tree algorithm implementations do. For example, [Catboost](https://catboost.ai/), or R's [rpart](https://cran.r-project.org/web/packages/rpart/index.html) package.
# - **Numeric Encoding:** Synonymous with Label Encoding, or "Ordinal" Encoding with random order. We can use [category_encoders.OrdinalEncoder](https://contrib.scikit-learn.org/categorical-encoding/ordinal.html).
# - **One-Hot Encoding:** We can use [category_encoders.OneHotEncoder](http://contrib.scikit-learn.org/categorical-encoding/onehot.html).
# - **Binary Encoding:** We can use [category_encoders.BinaryEncoder](http://contrib.scikit-learn.org/categorical-encoding/binary.html).
#
#
# **2.** The short video
# **[Coursera — How to Win a Data Science Competition: Learn from Top Kagglers — Concept of mean encoding](https://www.coursera.org/lecture/competitive-data-science/concept-of-mean-encoding-b5Gxv)** introduces an interesting idea: use both X _and_ y to encode categoricals.
#
# Category Encoders has multiple implementations of this general concept:
#
# - [CatBoost Encoder](http://contrib.scikit-learn.org/categorical-encoding/catboost.html)
# - [James-Stein Encoder](http://contrib.scikit-learn.org/categorical-encoding/jamesstein.html)
# - [Leave One Out](http://contrib.scikit-learn.org/categorical-encoding/leaveoneout.html)
# - [M-estimate](http://contrib.scikit-learn.org/categorical-encoding/mestimate.html)
# - [Target Encoder](http://contrib.scikit-learn.org/categorical-encoding/targetencoder.html)
# - [Weight of Evidence](http://contrib.scikit-learn.org/categorical-encoding/woe.html)
#
# Category Encoder's mean encoding implementations work for regression problems or binary classification problems.
#
# For multi-class classification problems, you will need to temporarily reformulate it as binary classification. For example:
#
# ```python
# encoder = ce.TargetEncoder(min_samples_leaf=..., smoothing=...) # Both parameters > 1 to avoid overfitting
# X_train_encoded = encoder.fit_transform(X_train, y_train=='functional')
# X_val_encoded = encoder.transform(X_train, y_val=='functional')
# ```
#
# For this reason, mean encoding won't work well within pipelines for multi-class classification problems.
#
# **3.** The **[dirty_cat](https://dirty-cat.github.io/stable/)** library has a Target Encoder implementation that works with multi-class classification.
#
# ```python
#  dirty_cat.TargetEncoder(clf_type='multiclass-clf')
# ```
# It also implements an interesting idea called ["Similarity Encoder" for dirty categories](https://www.slideshare.net/GaelVaroquaux/machine-learning-on-non-curated-data-154905090).
#
# However, it seems like dirty_cat doesn't handle missing values or unknown categories as well as category_encoders does. And you may need to use it with one column at a time, instead of with your whole dataframe.
#
# **4. [Embeddings](https://www.kaggle.com/learn/embeddings)** can work well with sparse / high cardinality categoricals.
#
# _**I hope it’s not too frustrating or confusing that there’s not one “canonical” way to encode categoricals. It’s an active area of research and experimentation! Maybe you can make your own contributions!**_

# %% [markdown]
# ### Setup
#
# You can work locally (follow the [local setup instructions](https://lambdaschool.github.io/ds/unit2/local/)) or on Colab (run the code cell below).

# %%
# %%capture
import sys

# Editing local, bulk processing in Colab!  Hence:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Kaggle-Challenge/master/data/'
    # !pip install category_encoders==2.*

# Primary location:
else:
    DATA_PATH = '../data/'

# %%
# %%capture
# !pip install folium
# !pip install category_encoders
# !pip install graphviz

# %%
import pandas as pd
import numpy as np
import folium
import plotly.express as px
import category_encoders as ce
import graphviz
import random, time, datetime

from sklearn.tree import export_graphviz
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from IPython.display import HTML, display, IFrame
from itertools import combinations

# %%
# for filenaming later

def timeStamp():
    ts = time.time()
    st = datetime.datetime.fromtimestamp(ts).strftime('%m%d_%H%M%S')
    return st

# %%
train = pd.merge(pd.read_csv(DATA_PATH+'waterpumps/train_features.csv'), 
                 pd.read_csv(DATA_PATH+'waterpumps/train_labels.csv'))
test = pd.read_csv(DATA_PATH+'waterpumps/test_features.csv')
sample_submission = pd.read_csv(DATA_PATH+'waterpumps/sample_submission.csv')

train, val = train_test_split(train, train_size=.8, test_size=.2, 
                              stratify=train['status_group'], random_state=55)

train.shape, val.shape, test.shape, sample_submission.shape
# Out:
# ((47520, 41), (11880, 41), (14358, 40), (14358, 2))

# %%
def cleanData(X):
    
    # Supress Warning
    X = X.copy()
    
    # Replace outlier lat vals with 0
    X['latitude'] = X['latitude'].replace(-2e-08, 0)
    
    # Replace 0's with np.nan for future imputing of values
    cols_w_zeros = ['longitude', 'latitude']
    for col in cols_w_zeros:
        X[col] = X[col].replace(0, np.nan)
    
    # Drop duplicate values
    X = X.drop(columns=['quantity_group', 'amount_tsh'])
    
    X['date_recorded'] = pd.to_datetime(X['date_recorded'])
    X['dd_recorded'] = X['date_recorded'].dt.day
    X['mm_recorded'] = X['date_recorded'].dt.month
    X['yyyy_recorded'] = X['date_recorded'].dt.year
    
    return X

# %%
train = cleanData(train)
val = cleanData(val)
test = cleanData(test)

# %%
# Constant target
target = 'status_group'

# Defining different features for future isolation
features_all = train.drop(columns=['status_group', 'id'])

# Isolate numeric features
features_numeric = features_all.select_dtypes(include='number').columns.tolist()

# Isolate object features
features_obj = features_all.select_dtypes(exclude='number').nunique()

# Split object features into high and low cardinal
features_obj_low = features_obj[features_obj <= 45].index.tolist()
features_obj_high = features_obj[features_obj > 45].index.tolist()

# %%
# function to call within models to log Validate Score

def logOutcome(model, features, modelVars, score):
    newLine = pd.DataFrame([[timeStamp(), model, features, 
                             modelVars, score]],
                           columns=['timestamp',
                                    'model',
                                    'featuresUsed',
                                    'modelVars',
                                    'valScore'])
    
    logDf = pd.read_csv('../tracking/loggingProcesses')
    logDf = logDf.append(newLine, ignore_index=True)
    logDf.to_csv('../tracking/loggingProcesses', index=False)

# %%
# ran once to create csv for logging:
#
# tempDF = pd.DataFrame(
#     {'timestamp': timeStamp(),
#      'model': 'modelUsed',
#      'featuresUsed': ['selectedFeatures'],
#      'modelVars': ['modelVariables'],
#      'valScore': 99.999
#     }
# )

# tempDF.to_csv('../tracking/loggingProcesses', index=False)

# %%
# I want to test on multiple fronts, different models & with different features
# Rather than redefine the features variable each time, I will assign chosen sets 

featuresAll = features_all.columns
features01 = features_numeric + features_obj_low
features02 = ['gps_height', 'longitude',
            'latitude', 'num_private', 'basin', 'region',
            'region_code', 'district_code', 'population',
            'public_meeting', 'recorded_by', 'scheme_management',
            'permit', 'construction_year', 'extraction_type',
            'extraction_type_class', 'management',
            'payment', 'water_quality',
            'quantity', 'source', 'source_type', 'source_class',
            'waterpoint_type',
            'mm_recorded', 'yyyy_recorded']

# %%
def runDecisionTreeModel(train, val, test, features, leaf, depth):
    '''
    - Runs decision tree on train/val/test df
    - Prints accuracy
    - Logs validate accuracy to exterior csv
    - Returns the y_pred list for use in competition submission. 
    '''
    
    state_num = random.randint(1, 100)
    
    pipeline = make_pipeline(
        ce.OneHotEncoder(use_cat_names=True),
        SimpleImputer(strategy='mean'),
        DecisionTreeClassifier(min_samples_leaf = leaf,
                               max_depth = depth,
                               random_state=state_num)
    )
    
    X_train = train[features]
    y_train = train[target]
    X_val = val[features]
    y_val = val[target]
    X_test = test[features]
    
    pipeline.fit(X_train, y_train)
    train_score = pipeline.score(X_train, y_train)
    val_score = pipeline.score(X_val, y_val)
    
    print('Decision Tree Accuracy: \nTrain:    ', train_score,
      '\nValidate: ', val_score, '\n')    
    
    modelVars = [['leaf', leaf],['depth', depth]]
    
    logOutcome('DecisionTree', features, modelVars, val_score)
    
    y_pred = pipeline.predict(X_test)
    
    return y_pred

# %%
def runRandomForestModel(train, val, test, features, estimators):
    '''
    - Runs Random Forest on train/val/test df
    - Prints accuracy
    - Logs validate accuracy to exterior csv
    - Returns the y_pred list for use in competition submission. 
    '''
    
    state_num = random.randint(1, 100)
    
    pipeline = make_pipeline(
        ce.OneHotEncoder(use_cat_names=True),
        SimpleImputer(strategy='mean'),
        RandomForestClassifier(n_estimators=estimators,
                               random_state=state_num,
                               n_jobs=-2)
    )
    
    X_train = train[features]
    y_train = train[target]
    X_val = val[features]
    y_val = val[target]
    X_test = test[features]
    
    pipeline.fit(X_train, y_train)
    train_score = pipeline.score(X_train, y_train)
    val_score = pipeline.score(X_val, y_val)
    
    print('Random Forest Accuracy: \nTrain:    ', train_score,
          '\nValidate: ', val_score, '\n')
    
    modelVars = [['estimators', estimators]]
    
    logOutcome('RandomForest', features, modelVars, val_score)
    
    y_pred = pipeline.predict(X_test)
    
    return y_pred

# %%
runRandomForestModel(train, val, test, features01, 100)
# Out:
# Random Forest Accuracy:
# Train:     0.9977483164983165
# Validate:  0.8035353535353535
# array(['functional', 'functional', 'functional', ..., 'functional',
#        'functional', 'non functional'], dtype=object)

# %%
runDecisionTreeModel(train, val, test, features02, 6, 21)
# Out:
# Decision Tree Accuracy:
# Train:     0.8431186868686869
# Validate:  0.7718855218855218
# array(['functional', 'functional', 'functional', ..., 'functional',
#        'functional', 'non functional'], dtype=object)

# %%
pd.read_csv('../tracking/loggingProcesses').head(10)
# Out:
#      timestamp         model  \
# 0  1106_133648     modelUsed
# 1  1106_133749  DecisionTree
# 2  1106_133812  RandomForest
# 3  1106_133925  RandomForest
# 4  1106_134115  DecisionTree
# 5  1106_134140  RandomForest
# 6  1106_135620  RandomForest
# 7  1106_140752  RandomForest
#
#                                         featuresUsed  \
# 0                                   selectedFeatures
# 1  ['gps_height', 'longitude', 'latitude', 'num_p...
# 2  ['gps_height', 'longitude', 'latitude', 'num_p...
# 3  ['gps_height', 'longitude', 'latitude', 'num_p...
# 4  ['gps_height', 'longitude', 'latitude', 'num_p...
# 5  ['gps_height', 'longitude', 'latitude', 'num_p...
# 6  ['gps_height', 'longitude', 'latitude', 'num_p...
# 7  ['gps_height', 'longitude', 'latitude', 'num_p...
#
#                       modelVars   valScore
# 0                modelVariables  99.999000
# 1  [['leaf', 7], ['depth', 20]]   0.771717
# 2         [['estimators', 100]]   0.804882
# 3         [['estimators', 100]]   0.808165
# 4  [['leaf', 6], ['depth', 21]]   0.771886
# 5         [['estimators', 100]]   0.806229
# 6         [['estimators', 100]]   0.805724
# 7         [['estimators', 100]]   0.803535

# %%
def saveSubmission(prediction, filename):
    savePath = '../submissions/'
    
    submission = sample_submission.copy()
    submission['status_group'] = prediction
    submission.to_csv(savePath+filename+'.csv', index=False)

# %%
y_pred = runDecisionTreeModel(train, val, test, features02, 7, 20)
saveSubmission(y_pred, 'testSave')
# Out:
# Decision Tree Accuracy:
# Train:     0.8332070707070707
# Validate:  0.7717171717171717

# %%
train.T.head(75)
# Out:
#                                          36168                    26059  \
# id                                       42669                    12317
# date_recorded              2011-02-25 00:00:00      2011-02-20 00:00:00
# funder                                     Mdc                      W.B
# gps_height                                1678                      106
# installer                                  DWE                      RDC
# longitude                              35.2946                  39.0643
# latitude                              -8.14543                 -7.62444
# wpt_name                                  none             Rashid Omari
# num_private                                  0                        0
# basin                                   Rufiji                   Rufiji
# subvillage                                   I                  Kibaoni
# region                                  Iringa                    Pwani
# region_code                                 11                       60
# district_code                                2                       53
# lga                                    Mufindi                   Rufiji
# ward                                 Isalavanu                    Bungu
# population                                   0                        1
# public_meeting                            True                     True
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                          VWC                      VWC
# scheme_name                                Mad                      NaN
# permit                                    True                     True
# construction_year                            0                     2004
# extraction_type                        gravity                     mono
# extraction_type_group                  gravity                     mono
# extraction_type_class                  gravity                motorpump
# management                                 vwc                      vwc
# management_group                    user-group               user-group
# payment                              never pay           pay per bucket
# payment_type                         never pay               per bucket
# water_quality                             soft                     soft
# quality_group                             good                     good
# quantity                                enough                   enough
# source                                  spring              machine dbh
# source_type                             spring                 borehole
# source_class                       groundwater              groundwater
# waterpoint_type             communal standpipe       communal standpipe
# waterpoint_type_group       communal standpipe       communal standpipe
# status_group                        functional               functional
# dd_recorded                                 25                       20
# mm_recorded                                  2                        2
# yyyy_recorded                             2011                     2011
#
#                                             13381                    11700  \
# id                                          18536                    13292
# date_recorded                 2013-03-27 00:00:00      2013-02-01 00:00:00
# funder                                   Mbiuwasa                    Rwssp
# gps_height                                   1299                        0
# installer                                MBIUWASA                      DWE
# longitude                                 34.9937                      NaN
# latitude                                 -10.9441                      NaN
# wpt_name               Karibu Na Kituo Cha Polisi                   Kasela
# num_private                                     0                        0
# basin                                  Lake Nyasa            Lake Victoria
# subvillage                            Polisi Line                Mwamalula
# region                                     Ruvuma                Shinyanga
# region_code                                    10                       17
# district_code                                   3                        1
# lga                                        Mbinga                  Bariadi
# ward                                 Mbinga Urban                  Nkololo
# population                                     96                        0
# public_meeting                                NaN                     True
# recorded_by               GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                     Water Board                      WUG
# scheme_name                                BRUDER                      NaN
# permit                                       True                    False
# construction_year                            2002                        0
# extraction_type                           gravity              nira/tanira
# extraction_type_group                     gravity              nira/tanira
# extraction_type_class                     gravity                 handpump
# management                            water board                      wug
# management_group                       user-group               user-group
# payment                                   unknown                never pay
# payment_type                              unknown                never pay
# water_quality                                soft          salty abandoned
# quality_group                                good                    salty
# quantity                             insufficient                   enough
# source                                     spring             shallow well
# source_type                                spring             shallow well
# source_class                          groundwater              groundwater
# waterpoint_type                communal standpipe                hand pump
# waterpoint_type_group          communal standpipe                hand pump
# status_group                           functional               functional
# dd_recorded                                    27                        1
# mm_recorded                                     3                        2
# yyyy_recorded                                2013                     2013
#
#                                          52628                    36213  \
# id                                       54594                    35130
# date_recorded              2011-03-25 00:00:00      2012-10-23 00:00:00
# funder                                Nethalan             World Vision
# gps_height                                 372                        0
# installer                                  RWE      Consulting Engineer
# longitude                              37.4522                  32.8673
# latitude                              -6.37716                 -4.12384
# wpt_name                            Kwa Ngosha      Kiriyandeta Mbugani
# num_private                                  0                        0
# basin                              Wami / Ruvu          Lake Tanganyika
# subvillage                             Subiria              Kiriyandeta
# region                                Morogoro                   Tabora
# region_code                                  5                       14
# district_code                                6                        1
# lga                                    Mvomero                    Nzega
# ward                                   Mvomero                  Ikindwa
# population                                   1                        0
# public_meeting                            True                     True
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                          VWC                      VWC
# scheme_name                                NaN                      NaN
# permit                                    True                    False
# construction_year                         1982                        0
# extraction_type                          other                    other
# extraction_type_group                    other                    other
# extraction_type_class                    other                    other
# management                                 vwc                      wug
# management_group                    user-group               user-group
# payment                              never pay    pay when scheme fails
# payment_type                         never pay               on failure
# water_quality                            salty                     soft
# quality_group                            salty                     good
# quantity                          insufficient                 seasonal
# source                            shallow well             shallow well
# source_type                       shallow well             shallow well
# source_class                       groundwater              groundwater
# waterpoint_type                          other                    other
# waterpoint_type_group                    other                    other
# status_group                    non functional           non functional
# dd_recorded                                 25                       23
# mm_recorded                                  3                       10
# yyyy_recorded                             2011                     2012
#
#                                          16839                    23826  \
# id                                       23993                    59447
# date_recorded              2011-02-18 00:00:00      2011-03-06 00:00:00
# funder                                   Tasaf                   Danida
# gps_height                                1677                     1535
# installer                                TASAF                    DANID
# longitude                              35.7603                  35.4827
# latitude                              -7.87806                 -7.75062
# wpt_name                                  none                     none
# num_private                                  0                        0
# basin                                   Rufiji                   Rufiji
# subvillage                    Luhota Secondary             Kinyamusaula
# region                                  Iringa                   Iringa
# region_code                                 11                       11
# district_code                                1                        1
# lga                               Iringa Rural             Iringa Rural
# ward                                 Magulilwa                    Nzihi
# population                                 950                        1
# public_meeting                            True                     True
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                          VWC                      VWC
# scheme_name                                NaN                    Nzihi
# permit                                    True                     True
# construction_year                         2009                     1994
# extraction_type                         swn 80                  gravity
# extraction_type_group                   swn 80                  gravity
# extraction_type_class                 handpump                  gravity
# management                                 vwc                      vwc
# management_group                    user-group               user-group
# payment                              never pay             pay annually
# payment_type                         never pay                 annually
# water_quality                             soft                     soft
# quality_group                             good                     good
# quantity                                enough                   enough
# source                             machine dbh                   spring
# source_type                           borehole                   spring
# source_class                       groundwater              groundwater
# waterpoint_type                      hand pump       communal standpipe
# waterpoint_type_group                hand pump       communal standpipe
# status_group                        functional               functional
# dd_recorded                                 18                        6
# mm_recorded                                  2                        3
# yyyy_recorded                             2011                     2011
#
#                                          38051                    41832  ...  \
# id                                       24944                    43279  ...
# date_recorded              2013-03-27 00:00:00      2011-03-12 00:00:00  ...
# funder                                  Unicef         China Government  ...
# gps_height                                1165                      239  ...
# installer                                  RWE                       Ch  ...
# longitude                              37.3055                  38.3105  ...
# latitude                              -3.26251                 -6.56136  ...
# wpt_name                       Kwa Peter Mushi          Shule Ya Zamani  ...
# num_private                                  0                        0  ...
# basin                                  Pangani              Wami / Ruvu  ...
# subvillage                              Masoka                Hospitali  ...
# region                             Kilimanjaro                    Pwani  ...
# region_code                                  3                        6  ...
# district_code                                4                        1  ...
# lga                                Moshi Rural                 Bagamoyo  ...
# ward                                    Kirima                   Lugoba  ...
# population                                 200                       56  ...
# public_meeting                            True                    False  ...
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd  ...
# scheme_management                          VWC                      WUA  ...
# scheme_name                   Utaruni pipeline            Chalinze wate  ...
# permit                                    True                     True  ...
# construction_year                         1980                     2003  ...
# extraction_type                        gravity                      ksb  ...
# extraction_type_group                  gravity              submersible  ...
# extraction_type_class                  gravity              submersible  ...
# management                                 vwc               parastatal  ...
# management_group                    user-group               parastatal  ...
# payment                              never pay              pay monthly  ...
# payment_type                         never pay                  monthly  ...
# water_quality                             soft                     soft  ...
# quality_group                             good                     good  ...
# quantity                          insufficient                   enough  ...
# source                                  spring                    river  ...
# source_type                             spring               river/lake  ...
# source_class                       groundwater                  surface  ...
# waterpoint_type             communal standpipe       communal standpipe  ...
# waterpoint_type_group       communal standpipe       communal standpipe  ...
# status_group                        functional               functional  ...
# dd_recorded                                 27                       12  ...
# mm_recorded                                  3                        3  ...
# yyyy_recorded                             2013                     2011  ...
#
#                                          7475                     8684   \
# id                                       10371                    23062
# date_recorded              2011-03-13 00:00:00      2013-02-04 00:00:00
# funder                      Private Individual                   Hesawa
# gps_height                                 204                     1429
# installer                                   WU                   Hesawa
# longitude                              38.3463                  34.4029
# latitude                              -6.63656                 -1.80129
# wpt_name                        Mama Mlamsanga                  Kyolang
# num_private                                  0                        0
# basin                              Wami / Ruvu            Lake Victoria
# subvillage                           Kiwanjani                   Kemeli
# region                                   Pwani                     Mara
# region_code                                  6                       20
# district_code                                1                        2
# lga                                   Bagamoyo                Serengeti
# ward                                  Chalinze                Nyamatare
# population                                  15                      300
# public_meeting                           False                     True
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                          WUA                      WUG
# scheme_name                      Chalinze wate                      NaN
# permit                                    True                      NaN
# construction_year                         2007                     1998
# extraction_type                            ksb        other - rope pump
# extraction_type_group              submersible                rope pump
# extraction_type_class              submersible                rope pump
# management                    private operator                      wug
# management_group                    commercial               user-group
# payment                         pay per bucket                never pay
# payment_type                        per bucket                never pay
# water_quality                             soft                     soft
# quality_group                             good                     good
# quantity                                enough                   enough
# source                                   river             shallow well
# source_type                         river/lake             shallow well
# source_class                           surface              groundwater
# waterpoint_type             communal standpipe                hand pump
# waterpoint_type_group       communal standpipe                hand pump
# status_group                        functional           non functional
# dd_recorded                                 13                        4
# mm_recorded                                  3                        2
# yyyy_recorded                             2011                     2013
#
#                                          22678                    58118  \
# id                                       50390                     7198
# date_recorded              2011-03-20 00:00:00      2011-07-22 00:00:00
# funder                                   Amref                   Tanapa
# gps_height                                  46                     1040
# installer                                AMREF                      DWE
# longitude                              39.0368                  31.1117
# latitude                              -7.44727                 -6.56175
# wpt_name                            Nguvu Kazi              Kwa Utitiri
# num_private                                  0                        0
# basin                                   Rufiji               Lake Rukwa
# subvillage                           Nguvukazi               Mugolokani
# region                                   Pwani                    Rukwa
# region_code                                  6                       15
# district_code                                4                        1
# lga                                   Mkuranga                   Mpanda
# ward                                   Nyamato                 Sitalike
# population                                 250                      360
# public_meeting                            True                     True
# recorded_by            GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                          VWC                      VWC
# scheme_name                                NaN                      NaN
# permit                                   False                     True
# construction_year                         2007                     2002
# extraction_type                  india mark ii              nira/tanira
# extraction_type_group            india mark ii              nira/tanira
# extraction_type_class                 handpump                 handpump
# management                                 vwc                      vwc
# management_group                    user-group               user-group
# payment                              never pay             pay annually
# payment_type                         never pay                 annually
# water_quality                            salty                    salty
# quality_group                            salty                    salty
# quantity                                enough                   enough
# source                             machine dbh                 hand dtw
# source_type                           borehole                 borehole
# source_class                       groundwater              groundwater
# waterpoint_type                      hand pump                hand pump
# waterpoint_type_group                hand pump                hand pump
# status_group                    non functional               functional
# dd_recorded                                 20                       22
# mm_recorded                                  3                        7
# yyyy_recorded                             2011                     2011
#
#                                             11218                    20523  \
# id                                          32403                    39562
# date_recorded                 2011-07-21 00:00:00      2012-10-06 00:00:00
# funder                                    Swedish              Netherlands
# gps_height                                      0                        0
# installer              Sengerema Water Department                      DWE
# longitude                                 32.4386                  33.9675
# latitude                                 -2.68061                 -3.11719
# wpt_name                               Kwa Makoye                  Neema B
# num_private                                     0                        0
# basin                               Lake Victoria            Lake Victoria
# subvillage                              Mwalolela                Mwabalogi
# region                                     Mwanza                Shinyanga
# region_code                                    19                       17
# district_code                                   5                        2
# lga                                     Sengerema                    Maswa
# ward                                   Buzilasoga               Ngulinguli
# population                                      0                        0
# public_meeting                               True                     True
# recorded_by               GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                             VWC                      WUG
# scheme_name                                  None                      NaN
# permit                                       True                    False
# construction_year                               0                        0
# extraction_type                       nira/tanira              nira/tanira
# extraction_type_group                 nira/tanira              nira/tanira
# extraction_type_class                    handpump                 handpump
# management                                    vwc                      wug
# management_group                       user-group               user-group
# payment                                 never pay                    other
# payment_type                            never pay                    other
# water_quality                               salty          salty abandoned
# quality_group                               salty                    salty
# quantity                                   enough                   enough
# source                               shallow well             shallow well
# source_type                          shallow well             shallow well
# source_class                          groundwater              groundwater
# waterpoint_type                         hand pump                hand pump
# waterpoint_type_group                   hand pump                hand pump
# status_group                       non functional               functional
# dd_recorded                                    21                        6
# mm_recorded                                     7                       10
# yyyy_recorded                                2011                     2012
#
#                                          35701                      51680  \
# id                                       39065                      51156
# date_recorded              2013-02-02 00:00:00        2013-01-18 00:00:00
# funder                            World Vision                      Tasaf
# gps_height                                   0                        222
# installer                          ADP Busangi  District water department
# longitude                              32.5514                    38.8984
# latitude                              -3.65055                   -9.97398
# wpt_name                             Upendeleo                    Kaliele
# num_private                                  0                          0
# basin                            Lake Victoria    Ruvuma / Southern Coast
# subvillage                              Kibama                     Dodoma
# region                               Shinyanga                      Lindi
# region_code                                 17                         80
# district_code                                3                         53
# lga                                     Kahama                    Ruangwa
# ward                                   Busangi                     Chunyu
# population                                   0                        198
# public_meeting                            True                       True
# recorded_by            GeoData Consultants Ltd    GeoData Consultants Ltd
# scheme_management                          NaN                        VWC
# scheme_name                                NaN                        NaN
# permit                                    True                      False
# construction_year                            0                       2010
# extraction_type                    nira/tanira                nira/tanira
# extraction_type_group              nira/tanira                nira/tanira
# extraction_type_class                 handpump                   handpump
# management                                 wug                        vwc
# management_group                    user-group                 user-group
# payment                                unknown                  never pay
# payment_type                           unknown                  never pay
# water_quality                            milky                       soft
# quality_group                            milky                       good
# quantity                              seasonal                     enough
# source                            shallow well               shallow well
# source_type                       shallow well               shallow well
# source_class                       groundwater                groundwater
# waterpoint_type                      hand pump                  hand pump
# waterpoint_type_group                hand pump                  hand pump
# status_group                        functional             non functional
# dd_recorded                                  2                         18
# mm_recorded                                  2                          1
# yyyy_recorded                             2013                       2013
#
#                                              35496                    35306
# id                                           36369                     3762
# date_recorded                  2011-07-20 00:00:00      2011-07-20 00:00:00
# funder                                    Wananchi                        P
# gps_height                                       0                        0
# installer                                 wananchi                        P
# longitude                                  33.7471                  32.9199
# latitude                                   -9.5715                 -2.47668
# wpt_name                          Kwa Enosi Fijabo         Kwa Primi Mazula
# num_private                                      0                        0
# basin                                   Lake Nyasa            Lake Victoria
# subvillage                                    Kati                        1
# region                                       Mbeya                   Mwanza
# region_code                                     12                       19
# district_code                                    3                        8
# lga                                          Kyela                  Ilemela
# ward                                         Ngana                  Ilemela
# population                                       0                        0
# public_meeting                                True                    False
# recorded_by                GeoData Consultants Ltd  GeoData Consultants Ltd
# scheme_management                  Water authority         Private operator
# scheme_name            Ngana water supplied scheme                      NaN
# permit                                        True                     True
# construction_year                                0                        0
# extraction_type                            gravity                   swn 80
# extraction_type_group                      gravity                   swn 80
# extraction_type_class                      gravity                 handpump
# management                         water authority         private operator
# management_group                        commercial               commercial
# payment                                pay monthly           pay per bucket
# payment_type                               monthly               per bucket
# water_quality                                 soft                    salty
# quality_group                                 good                    salty
# quantity                                    enough                   enough
# source                                      spring             shallow well
# source_type                                 spring             shallow well
# source_class                           groundwater              groundwater
# waterpoint_type                 communal standpipe                hand pump
# waterpoint_type_group           communal standpipe                hand pump
# status_group                            functional               functional
# dd_recorded                                     20                       20
# mm_recorded                                      7                        7
# yyyy_recorded                                 2011                     2011
#
# [42 rows x 47520 columns]

# %%
#  
def draw_comm(G, target, pos):
    fig, ax = plt.subplots(figsize = (16,9))
