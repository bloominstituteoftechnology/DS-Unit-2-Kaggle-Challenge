# %% [markdown]
# <a href="https://colab.research.google.com/github/JeremySpradlin/DS-Unit-2-Kaggle-Challenge/blob/master/module3-cross-validation/Jeremy_Spradlin_LS_DS_223_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lambda School Data Science
#
# *Unit 2, Sprint 2, Module 3*
#
# ---

# %% [markdown]
# # Cross-Validation
#
#
# ## Assignment
# - [ ] [Review requirements for your portfolio project](https://lambdaschool.github.io/ds/unit2), then submit your dataset.
# - [ ] Continue to participate in our Kaggle challenge.
# - [ ] Use scikit-learn for hyperparameter optimization with RandomizedSearchCV.
# - [ ] Submit your predictions to our Kaggle competition. (Go to our Kaggle InClass competition webpage. Use the blue **Submit Predictions** button to upload your CSV file. Or you can use the Kaggle API to submit your predictions.)
# - [ ] Commit your notebook to your fork of the GitHub repo.
#
#
# **You can't just copy** from the lesson notebook to this assignment.
#
# - Because the lesson was **regression**, but the assignment is **classification.**
# - Because the lesson used [TargetEncoder](https://contrib.scikit-learn.org/categorical-encoding/targetencoder.html), which doesn't work as-is for _multi-class_ classification.
#
# So you will have to adapt the example, which is good real-world practice.
#
# 1. Use a model for classification, such as [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)
# 2. Use hyperparameters that match the classifier, such as `randomforestclassifier__ ...`
# 3. Use a metric for classification, such as [`scoring='accuracy'`](https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values)
# 4. If you’re doing a multi-class classification problem — such as whether a waterpump is functional, functional needs repair, or nonfunctional — then use a categorical encoding that works for multi-class classification, such as [OrdinalEncoder](https://contrib.scikit-learn.org/categorical-encoding/ordinal.html) (not [TargetEncoder](https://contrib.scikit-learn.org/categorical-encoding/targetencoder.html))
#
#
#
# ## Stretch Goals
#
# ### Reading
# - Jake VanderPlas, [Python Data Science Handbook, Chapter 5.3](https://jakevdp.github.io/PythonDataScienceHandbook/05.03-hyperparameters-and-model-validation.html), Hyperparameters and Model Validation
# - Jake VanderPlas, [Statistics for Hackers](https://speakerdeck.com/jakevdp/statistics-for-hackers?slide=107)
# - Ron Zacharski, [A Programmer's Guide to Data Mining, Chapter 5](http://guidetodatamining.com/chapter5/), 10-fold cross validation
# - Sebastian Raschka, [A Basic Pipeline and Grid Search Setup](https://github.com/rasbt/python-machine-learning-book/blob/master/code/bonus/svm_iris_pipeline_and_gridsearch.ipynb)
# - Peter Worcester, [A Comparison of Grid Search and Randomized Search Using Scikit Learn](https://blog.usejournal.com/a-comparison-of-grid-search-and-randomized-search-using-scikit-learn-29823179bc85)
#
# ### Doing
# - Add your own stretch goals!
# - Try other [categorical encodings](https://contrib.scikit-learn.org/categorical-encoding/). See the previous assignment notebook for details.
# - In additon to `RandomizedSearchCV`, scikit-learn has [`GridSearchCV`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html). Another library called scikit-optimize has [`BayesSearchCV`](https://scikit-optimize.github.io/notebooks/sklearn-gridsearchcv-replacement.html). Experiment with these alternatives.
# - _[Introduction to Machine Learning with Python](http://shop.oreilly.com/product/0636920030515.do)_ discusses options for "Grid-Searching Which Model To Use" in Chapter 6:
#
# > You can even go further in combining GridSearchCV and Pipeline: it is also possible to search over the actual steps being performed in the pipeline (say whether to use StandardScaler or MinMaxScaler). This leads to an even bigger search space and should be considered carefully. Trying all possible solutions is usually not a viable machine learning strategy. However, here is an example comparing a RandomForestClassifier and an SVC ...
#
# The example is shown in [the accompanying notebook](https://github.com/amueller/introduction_to_ml_with_python/blob/master/06-algorithm-chains-and-pipelines.ipynb), code cells 35-37. Could you apply this concept to your own pipelines?

# %% [markdown]
# ### BONUS: Stacking!
#
# Here's some code you can use to "stack" multiple submissions, which is another form of ensembling:
#
# ```python
# import pandas as pd
#
# # Filenames of your submissions you want to ensemble
# files = ['submission-01.csv', 'submission-02.csv', 'submission-03.csv']
#
# target = 'status_group'
# submissions = (pd.read_csv(file)[[target]] for file in files)
# ensemble = pd.concat(submissions, axis='columns')
# majority_vote = ensemble.mode(axis='columns')[0]
#
# sample_submission = pd.read_csv('sample_submission.csv')
# submission = sample_submission.copy()
# submission[target] = majority_vote
# submission.to_csv('my-ultimate-ensemble-submission.csv', index=False)
# ```

# %%
# %%capture
import sys

# If you're on Colab:
if 'google.colab' in sys.modules:
    DATA_PATH = 'https://raw.githubusercontent.com/LambdaSchool/DS-Unit-2-Kaggle-Challenge/master/data/'
    # !pip install category_encoders==2.*

# If you're working locally:
else:
    DATA_PATH = '../data/'

# %%
import pandas as pd

# Merge train_features.csv & train_labels.csv
train = pd.merge(pd.read_csv(DATA_PATH+'waterpumps/train_features.csv'), 
                 pd.read_csv(DATA_PATH+'waterpumps/train_labels.csv'))

# Read test_features.csv & sample_submission.csv
test = pd.read_csv(DATA_PATH+'waterpumps/test_features.csv')
sample_submission = pd.read_csv(DATA_PATH+'waterpumps/sample_submission.csv')

# %% [markdown]
# # Imports
# My imports for my assignment will be added below as they are required

# %%
#Imports
from pandas_profiling import ProfileReport

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest

from category_encoders import OneHotEncoder, OrdinalEncoder, TargetEncoder

import numpy as np
from scipy.stats import randint, uniform
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Exploratory Data Analaysis
#
# We've been conducting exploratory analysis on the data throughout the week and will be continuing the same cleaning and organization strategy on today's assignment.  Any new EDA that occurs will be done here, and the strategies for using it included below in the `wrangle()` function.

# %%
train.head()
# Out:
#       id  amount_tsh  ... waterpoint_type_group    status_group
# 0  69572      6000.0  ...    communal standpipe      functional
# 1   8776         0.0  ...    communal standpipe      functional
# 2  34310        25.0  ...    communal standpipe      functional
# 3  67743         0.0  ...    communal standpipe  non functional
# 4  19728         0.0  ...    communal standpipe      functional
#
# [5 rows x 41 columns]

# %% [markdown]
# # Train-Validate-Test Split
# Split our data into our train-avl-test sets for training and validation

# %%
#Perform our train/test/split on the data
train, val  = train_test_split(train, train_size=0.8, test_size=0.2, stratify=train['status_group'], random_state=42)
train.shape, val.shape, test.shape
# Out:
# ((47520, 41), (11880, 41), (14358, 40))

# %% [markdown]
# # Baseline
#
# Determining our Baseline

# %%
train['status_group'].value_counts()
# Out:
# functional                 25807
# non functional             18259
# functional needs repair     3454
# Name: status_group, dtype: int64

# %%
baseline = (25807 / (25807 + 18259 + 3454))

print('Our naive baseline is: ', baseline)
# Out:
# Our naive baseline is:  0.5430765993265994

# %% [markdown]
# # Wrangle our Data
#
# Our function for wrangling our data before fitting and validation

# %%
#Create a function to wrangle our data by fixing the null island values in the geo data as well as 
#remove any redundant columns
def wrangle_data(X):
  """Function for wrangling all of our data sets in the same manner"""

  #Prevent a SettingWithCopyWarning
  X = X.copy()

  #Replace the near-0 values in latitude with 0's for easier handling
  X['latitude'] = X['latitude'].replace(-2e-08, 0)

  #Now we will replace the 0's with null values for easier handling
  cols_with_zeros = ['longitude', 'latitude', 'construction_year',
                     'gps_height', 'population']
  for col in cols_with_zeros:
    X[col] = X[col].replace(0, np.nan)
    X[col+'_MISSING'] = X[col].isnull()

  #Drop redundant or non-useful columns
  red_cols = ['quantity_group', 'payment_type', 'recorded_by', 'id']
  X = X.drop(columns=red_cols)

  #Convert date_recorded to a datetime object
  X['date_recorded'] = pd.to_datetime(X['date_recorded'], infer_datetime_format = True)

  #Extract the date elements and then drop the original date/time column
  X['year_recorded'] = X['date_recorded'].dt.year
  X['month_recorded'] = X['date_recorded'].dt.month
  X['day_recorded'] = X['date_recorded'].dt.day
  X = X.drop(columns='date_recorded')

  #Engineering new features
  X['years'] = X['year_recorded'] - X['construction_year']
  X['years_MISSING'] = X['years'].isnull()

  #Return the wrangled dataframe
  return X

# %%
#Perform our wrangling function on our 3 datasets
train = wrangle_data(train)
val = wrangle_data(val)
test = wrangle_data(test)

train.shape, val.shape, test.shape
# Out:
# ((47520, 46), (11880, 46), (14358, 45))

# %% [markdown]
# # Select our Features
#
# Here we will select our features that we will use in our model, as well as break out our wrangled data into feature sets and target sets

# %%
#Our target column
target = 'status_group'

# Strip out the target and id columns
train_features = train.drop(columns=[target])

#Get a list of numeric features
numeric_features = train_features.select_dtypes(include='number').columns.tolist()

#Get a series with the cardinality of the nonnumeric features
cardinality = train_features.select_dtypes(exclude='number').nunique()

#Create a list of all nonnumerica features with a cardinality <= 50
categorical_features = cardinality[cardinality <= 50].index.tolist()

#Combine the lists
features = numeric_features + categorical_features

print(features)
# Out:
# ['amount_tsh', 'gps_height', 'longitude', 'latitude', 'num_private', 'region_code', 'district_code', 'population', 'construction_year', 'year_recorded', 'month_recorded', 'day_recorded', 'years', 'basin', 'region', 'public_meeting', 'scheme_management', 'permit', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'water_quality', 'quality_group', 'quantity', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'longitude_MISSING', 'latitude_MISSING', 'construction_year_MISSING', 'gps_height_MISSING', 'population_MISSING', 'years_MISSING']

# %%
# Arrange data into X features matrix and y target vector 
X_train = train[features]
y_train = train[target]
X_val = val[features]
y_val = val[target]
X_test = test[features]

# %% [markdown]
# #Create our Pipeline
#
# Today we will also want to include cross validation as well as testing for best hyperparamter tuning

# %%
#Create our pipeline / We will start with the pipeline from yesterday's assignment since it worked so well
model = make_pipeline(
    OrdinalEncoder(),
    SimpleImputer(),
    StandardScaler(),
    SelectKBest(),
    RandomForestClassifier(criterion='entropy')
)
model
# Out:
# Pipeline(memory=None,
#          steps=[('ordinalencoder',
#                  OrdinalEncoder(cols=None, drop_invariant=False,
#                                 handle_missing='value', handle_unknown='value',
#                                 mapping=None, return_df=True, verbose=0)),
#                 ('simpleimputer',
#                  SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#                                missing_values=nan, strategy='mean',
#                                verbose=0)),
#                 ('standardscaler',
#                  StandardScaler(copy=True, with_...
#                  RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                         class_weight=None, criterion='entropy',
#                                         max_depth=None, max_features='auto',
#                                         max_leaf_nodes=None, max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=None,
#                                         oob_score=False, random_state=None,
#                                         verbose=0, warm_start=False))],
#          verbose=False)

# %%
#Create our parameters
param_dist1 = {     
    'simpleimputer__strategy': ['mean', 'median'],
    'selectkbest__k': range(1, len(X_train.columns)+1),
    'randomforestclassifier__n_estimators': randint(50, 500), 
    'randomforestclassifier__max_depth': [5, 10, 15, 20, 25, 30, 35, 40, None], 
    'randomforestclassifier__max_features': uniform(0, 1), 
}

# %%
#Create our search
search = RandomizedSearchCV(
    model,
    param_distributions=param_dist1,
    n_iter=30,
    cv=5,
    scoring='accuracy',
    verbose=30,
    return_train_score=True,
    n_jobs=-1
)

# %%
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   27.0s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   28.4s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   54.1s
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:   55.8s
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  1.7min
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 15.5min
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 15.7min
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 15.9min
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 16.0min
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 16.1min
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 16.2min
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 17.7min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 19.0min
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 20.4min
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 20.5min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 21.8min
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 23.3min
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 23.4min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 26.5min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 26.9min
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 27.3min
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 27.6min
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 28.0min
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 28.2min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 28.4min
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 28.7min
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 28.8min
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 29.2min
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 29.5min
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 31.2min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 31.5min
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 33.2min
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 33.6min
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 34.7min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 35.2min
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 35.8min
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 36.3min
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 36.9min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 37.2min
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 37.5min
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 37.5min
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 37.8min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 37.9min
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 38.6min
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 38.8min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 39.3min
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 39.5min
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 40.0min
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 41.7min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 42.1min
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 43.9min
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 44.3min
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 45.5min
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 46.1min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 46.3min
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 46.9min
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed: 47.1min
# [Parallel(n_jobs=-1)]: Done 115 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 116 tasks      | elapsed: 47.7min
# [Parallel(n_jobs=-1)]: Done 117 tasks      | elapsed: 48.2min
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed: 48.3min
# [Parallel(n_jobs=-1)]: Done 119 tasks      | elapsed: 48.7min
# [Parallel(n_jobs=-1)]: Done 120 tasks      | elapsed: 48.8min
# [Parallel(n_jobs=-1)]: Done 121 tasks      | elapsed: 49.9min
# [Parallel(n_jobs=-1)]: Done 122 tasks      | elapsed: 50.0min
# [Parallel(n_jobs=-1)]: Done 123 tasks      | elapsed: 51.1min
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed: 51.2min
# [Parallel(n_jobs=-1)]: Done 125 tasks      | elapsed: 51.5min
# [Parallel(n_jobs=-1)]: Done 126 tasks      | elapsed: 51.9min
# [Parallel(n_jobs=-1)]: Done 127 tasks      | elapsed: 52.2min
# [Parallel(n_jobs=-1)]: Done 128 tasks      | elapsed: 52.3min
# [Parallel(n_jobs=-1)]: Done 129 tasks      | elapsed: 52.5min
# [Parallel(n_jobs=-1)]: Done 130 tasks      | elapsed: 52.6min
# [Parallel(n_jobs=-1)]: Done 131 tasks      | elapsed: 53.4min
# [Parallel(n_jobs=-1)]: Done 132 tasks      | elapsed: 53.4min
# [Parallel(n_jobs=-1)]: Done 133 tasks      | elapsed: 54.1min
# [Parallel(n_jobs=-1)]: Done 134 tasks      | elapsed: 54.2min
# [Parallel(n_jobs=-1)]: Done 135 tasks      | elapsed: 54.9min
# [Parallel(n_jobs=-1)]: Done 136 tasks      | elapsed: 55.6min
# [Parallel(n_jobs=-1)]: Done 137 tasks      | elapsed: 56.4min
# [Parallel(n_jobs=-1)]: Done 138 tasks      | elapsed: 57.1min
# [Parallel(n_jobs=-1)]: Done 139 tasks      | elapsed: 57.8min
# [Parallel(n_jobs=-1)]: Done 140 tasks      | elapsed: 58.0min
# [Parallel(n_jobs=-1)]: Done 141 tasks      | elapsed: 58.1min
# [Parallel(n_jobs=-1)]: Done 142 tasks      | elapsed: 58.2min
# [Parallel(n_jobs=-1)]: Done 143 tasks      | elapsed: 58.3min
# [Parallel(n_jobs=-1)]: Done 144 tasks      | elapsed: 58.5min
# [Parallel(n_jobs=-1)]: Done 145 tasks      | elapsed: 58.6min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 58.7min
# [Parallel(n_jobs=-1)]: Done 147 tasks      | elapsed: 58.9min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 59.3min finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=Pipeline(memory=None,
#                                       steps=[('ordinalencoder',
#                                               OrdinalEncoder(cols=None,
#                                                              drop_invariant=False,
#                                                              handle_missing='value',
#                                                              handle_unknown='value',
#                                                              mapping=None,
#                                                              return_df=True,
#                                                              verbose=0)),
#                                              ('simpleimputer',
#                                               SimpleImputer(add_indicator=False,
#                                                             copy=True,
#                                                             fill_value=None,
#                                                             missing_values=nan,
#                                                             strategy='mean',
#                                                             verbose=0)...
#                                         'randomforestclassifier__max_features': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f6028790dd8>,
#                                         'randomforestclassifier__n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f6028790c88>,
#                                         'selectkbest__k': range(1, 39),
#                                         'simpleimputer__strategy': ['mean',
#                                                                     'median']},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=True, scoring='accuracy', verbose=30)

# %%
print('Cross-validation Best Score', search.best_score_)
print('Best Estimator', search.best_params_)
# Out:
# Cross-validation Best Score 0.8008417508417507
# Best Estimator {'randomforestclassifier__max_depth': 15, 'randomforestclassifier__max_features': 0.21138491554884387, 'randomforestclassifier__n_estimators': 413, 'selectkbest__k': 38, 'simpleimputer__strategy': 'mean'}
